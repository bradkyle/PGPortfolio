# %%
from oauth2client.client import GoogleCredentials
from googleapiclient import discovery
import random
import numpy as np
import requests

# %%
PROJECT='backup-221409'
MODEL='AXIOM_AGENT_bitfinex_btc_90'
VERSION='btc_nnagent_90_ws_900_gp_3fn'

# %%
credentials = GoogleCredentials.get_application_default()
api = discovery.build('ml', 'v1', credentials=credentials)

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("Data.db")
cur = conn.cursor()
coords = cur.execute("""
  SELECT * FROM Bitfinex_BTC"""
).fetchall()
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 28))
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-6-983659bde1ea> in <module>()
#       5 cur = conn.cursor()
#       6 coords = cur.execute("""
# ----> 7   SELECT * FROM Bitfinex_BTC"""
#       8 ).fetchall()
#
# OperationalError: no such table: Bitfinex_BTC

# %%
import json
with open("data_1.json") as f:
    data = json.load(f)

# %%
inp=data['instances'][0]['input']
prev_w=data['instances'][0]['previous_w']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-57931931b85f> in <module>()
# ----> 1 inp=data['instances'][0]['input']
#       2 prev_w=data['instances'][0]['previous_w']
#
# NameError: name 'data' is not defined

# %%
prev_w

# %%
x = [0.0, 0.0, 8.814245860966352e-11, 7.588777606315489e-08, 0.9865739941596985, 0.0, 0.013425826095044613, 1.2748067724825371e-26, 2.0143470225164606e-11, 3.605106209872182e-37, 0.0, 3.0940070384205542e-12, 7.186712891460445e-10, 0.0, 4.114956977260402e-32, 9.777588957626715e-37]

# %%
len(x)

# %%
name = 'projects/{}/models/{}'.format(PROJECT, MODEL)
if VERSION is not None:
        name += '/versions/{}'.format(VERSION)

response = api.projects().predict(
        name=name,
        body=data
    ).execute()

# %%
if 'error' in response:
        raise RuntimeError(response['error'])

print(response['predictions'])

# %%
def parse_response():

# %%
output=response['predictions'][0]['output']

# %%
prev_w=data['instances'][0]['previous_w'][0]

# %% [markdown]
# ## output is larger than input to account for base currency

# %%
len(output)

# %%
len(prev_w)
