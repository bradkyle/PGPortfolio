# %%
import sqlite3
import pandas as pd
# Create your connection.
db = sqlite3.connect('../database/BitfinexData.db')

# %%
cursor = db.cursor()

# %%
table = "Bitfinex_BTC"

# %%
sql = ';'.format(table=table);

# %%
cursor.execute(sql, (int(start), int(end), self._coin_number))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a1b6a4890e16> in <module>()
# ----> 1 cursor.execute(sql, (int(start), int(end), self._coin_number))
#
# NameError: name 'start' is not defined

# %%
df = pd.read_sql_query("SELECT * FROM Bitfinex_BTC LIMIT 100", db)

# %%
df
# Out:
#     index          date      open     close      high       low  \
# 0       0  1.523118e+09  0.000020  0.000020  0.000020  0.000020
# 1       1  1.523125e+09  0.000002  0.000002  0.000002  0.000002
# 2       2  1.523128e+09  0.000020  0.000020  0.000020  0.000020
# 3       3  1.523128e+09  0.000020  0.000020  0.000020  0.000020
# 4       4  1.523128e+09  0.000020  0.000020  0.000020  0.000020
# 5       5  1.523134e+09  0.000019  0.000020  0.000020  0.000019
# 6       6  1.523139e+09  0.000017  0.000017  0.000017  0.000017
# 7       7  1.523139e+09  0.000020  0.000020  0.000020  0.000020
# 8       8  1.523140e+09  0.000020  0.000020  0.000020  0.000020
# 9       9  1.523150e+09  0.000020  0.000020  0.000020  0.000020
# 10     10  1.523152e+09  0.000019  0.000019  0.000019  0.000019
# 11     11  1.523152e+09  0.000019  0.000019  0.000019  0.000019
# 12     12  1.523154e+09  0.000019  0.000019  0.000019  0.000019
# 13     13  1.523163e+09  0.000019  0.000019  0.000019  0.000019
# ...
