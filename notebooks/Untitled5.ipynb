# %%
import numpy as np

# %%
x = [ [ 0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667,
    0.06666666666666667 ] ]

# %%
y = [ [ 0,
    0.0004992660833522677,
    0.001897713984362781,
    0.7743334174156189,
    0,
    0.22317439317703247,
    5.731956576049413e-12,
    0.000045247081288835034,
    9.548832701480262e-17,
    1.0798163283613795e-35,
    0.000005875654096598737,
    0.00004410596375237219,
    0,
    1.8773338393280985e-14,
    1.501233947156933e-16 ] ]

# %%
z = np.subtract(x,y)

# %%
z
# Out:
# array([[-0.06666667, -0.0661674 , -0.06476895,  0.70766675, -0.06666667,
#          0.15650773, -0.06666667, -0.06662142, -0.06666667, -0.06666667,
#         -0.06666079, -0.06662256, -0.06666667, -0.06666667, -0.06666667]])

# %%
np.sum(z)
# Out:
# 1.9365255315983987e-08
