// %%
function myFunc(arg) {
  console.log(`arg was => ${arg}`);
}

setTimeout(myFunc, 3000, 'funky');
// Out:
// Timeout {
//   _called: false,
//   _idleTimeout: 3000,
//   _idlePrev:
//    TimersList {
//      _idleNext: [Circular],
//      _idlePrev: [Circular],
//      _unrefed: false,
//      msecs: 3000,
//      _timer: Timer { _list: [Circular] } },
//   _idleNext:
//    TimersList {
//      _idleNext: [Circular],
//      _idlePrev: [Circular],
//      _unrefed: false,
//      msecs: 3000,
//      _timer: Timer { _list: [Circular] } },
//   _idleStart: 506729,
//   _onTimeout: [Function: myFunc],
//   _timerArgs: [ 'funky' ],
//   _repeat: null,
//   _destroyed: false,
//   [Symbol(unrefed)]: false,
//   [Symbol(asyncId)]: 18,
//   [Symbol(triggerId)]: 15 }
// arg was => funky
