// %%
var nj = require('numjs');

// %%
var x = nj.array([0.1,0.1,0.2,0.3,0.1,0.1,0.1])

// %%
var y = nj.array([0.0,0.3,0.1,0.1,0.1,0.2,0.1])

// %%
var z = y.add(nj.negative(x))

// %%
z.tolist()
// Out:
// [ -0.1, 0.19999999999999998, -0.1, -0.19999999999999998, 0, 0.1, 0 ]

// %%
function pos(arr) {
    let pos_arr = nj.array();
    
}
// Out:
// 0.9999999999999999

// %%
function neg(arr) {
    let neg_arr = nj.array();
    
}
