# %%
# !gcloud ml-engine models list
# Out:
# NAME             DEFAULT_VERSION_NAME
# Bitfinex_900_15  step_150000
# Bitfinex_900_30
# Poloniex         Poloniex

# %%
from oauth2client.client import GoogleCredentials
from googleapiclient import discovery
import random
import numpy as np
import requests

# %%
PROJECT='axiom-209217'
MODEL='test'
VERSION='test_1'

# %%
credentials = GoogleCredentials.get_application_default()
api = discovery.build('ml', 'v1', credentials=credentials)

# %%
import json
with open("data.json") as f:
    data = json.load(f)

# %%
print(np.array(data['instances'][0]['input']).shape)
print(np.array(data['instances'][0]['previous_w']).shape)
print(np.array(np.array(data['instances'][0]['input_num']).shape))
# Out:
# (3, 15, 90)
# (15,)
# []

# %%
parent = 'projects/%s/models/%s/versions/%s' % (PROJECT, MODEL, VERSION)
response = api.projects().predict(body=data, name=parent).execute()
print( "response={0}".format(response))
# Out:
# response={'error': 'Prediction failed: Error during model execution: AbortionError(code=StatusCode.INVALID_ARGUMENT, details="Shapes of all inputs must match: values[0].shape = [1] != values[1].shape = []\n\t [[Node: Reshape/shape = Pack[N=4, T=DT_INT32, _output_shapes=[[4]], axis=0, _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_input_num_0_0, Reshape/shape/1, Tile/multiples/1, Reshape/shape/3)]]")'}
